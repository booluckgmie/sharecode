# %% [markdown]
# ## Harga Harta Kediaman

# %% [markdown]
# single

# %%
import pandas as pd
from io import BytesIO
import requests
import numpy as np

# Sample URLs
urls = [
    "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/WP KL/Jadual Harga dan Sewa WPKL LPH 2022.xlsx",
    # "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/WP LABUAN/Jadual Harga dan Sewa  Labuan LPH 2022.xlsx",
    # Add more URLs here
]

# Create an empty list to store DataFrames
dfs = []

# Specify the sheet names you want to read
target_sheets = ['.1']  # Sheets ending with '.1' or '.3'

# Iterate through each URL
for url in urls:
    # Get the content of the file from the URL
    response = requests.get(url)
    
    # Read sheets that match the criteria
    xls = pd.ExcelFile(BytesIO(response.content))
    sheet_names = [sheet for sheet in xls.sheet_names if sheet.endswith(tuple(target_sheets))]
    
    # Extract relevant information from the URL
    url_parts = url.split('/')
    url_file = f"{url_parts[-3]}/{url_parts[-2]}"
    
    # Iterate through each sheet
    for sheet in sheet_names:
        # Read the sheet into a DataFrame
        df = pd.read_excel(xls, sheet_name=sheet, skiprows=5)#,
        df.columns = ['district_mukim','sample_size','avg_landsm','avg_floorsm','price_2021','price_2022','avg_pricePerct']
        df = df.iloc[1:]
        
        # Drop rows with all NaN values
        df = df.dropna(how='all')
        
        # Check if df[1] is NaN and use df[0] value for a new column 'location'
        df['location'] = np.where(pd.isna(df[df.columns[1]]), df[df.columns[0]], df[df.columns[1]])
        df['location'] = df['location'].astype(str)
                
        # Identify strings containing numbers and replace with NaN
        pattern = r'\d'  # Regular expression to match any digit
        df['location'] = df['location'].where(~df['location'].str.contains(pattern), np.nan)

        # Forward-fill the 'location' column
        df['location'] = df['location'].fillna(method='ffill')
        
        # Create a new column 'types' at rows where df[0] is in uppercase
        df['types'] = np.where(df[df.columns[0]].str.isupper(), df[df.columns[0]], np.nan)
        
        # Forward-fill the 'types' column until a different value is encountered
        df['types'] = df['types'].fillna(method='ffill')

        # Remove rows where 'district_mukim' is equal to 'location'
        df = df[df[df.columns[0]] != df[df.columns[7]]]
        
        # Assuming df is your DataFrame
        df = df.dropna(subset=['sample_size'])
                
        # Add a new column 'filename' with the extracted information
        df['source'] = url_file
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
final_result_df = pd.concat(dfs, ignore_index=True)

# Display the final result DataFrame
final_result_df.head(30)
# Out:
#                             district_mukim  sample_size  avg_landsm  \
# 0             Salak South Low Cost Housing          1.0  102.190000
# 1                 Bandar Baru Sri Petaling          1.0  143.000000
# 2                              Kepong Baru          1.0  132.847000
# 3                       Taman Sri Segambut          1.0  136.560000
# 4                          Wangsa Melawati          1.0  108.000000
# 5                       Salak South Garden          1.0  143.000000
# 6                           Million Garden          1.0  124.114000
# 7                             Taman Golden          1.0  139.350000
# 8                         Ipoh Road Garden          1.0  134.000000
# 9                              Kepong Baru         19.0  140.379526
# 10                           Kepong Garden          3.0  142.666667
# 11                       Taman Desa Bakti           2.0  139.000000
# 12                      Taman Bukit Maluri          6.0  164.833333
# 13                           Taman Kok Doh          2.0  132.848500
# 14                           Taman Rainbow          1.0  189.000000
# 15  Taman Sri Delima (PKNS Housing Scheme)          2.0  153.192000
# 16                      Taman Sri Segambut          4.0  136.780750
# 17                    Taman Lembah Keramat          1.0  140.000000
# 18                          Bukit Anggerik          1.0  153.000000
# 19                      Taman Bukit Cheras          5.0  143.600000
# 20   Bandar Tun Abd Razak (Kampung Konggo)          2.0  149.000000
# 21                      Bandaraya Petaling          1.0  173.730000
# 22                            Bangsar Baru          2.0  173.723000
# 23                            Bangsar Park          3.0  173.766667
# 24           Lucky Garden  (Jalan Bangsar)          1.0  163.000000
# 25                            Taynton View          5.0  154.000000
# 26            Taman Cheras (Yulek Heights)          2.0  138.883500
# 27                             Taman Midah          5.0  143.200000
# 28                     Taman Tun Dr Ismail          5.0  175.300800
# 29                Bandar Baru Sri Petaling          3.0  186.000000
#
#     avg_floorsm             price_2021             price_2022 avg_pricePerct  \
# 0     81.750000                    NaN                 200000             ND
# 1     86.405000                    NaN                 610000             ND
# 2    107.300000                    NaN                 530000             ND
# 3     96.575000                    NaN                 485000             ND
# 4    107.950000                    NaN                 630000             ND
# 5     86.860000                    NaN                 560000             ND
# 6     83.610000                    NaN                 700000             ND
# 7    104.795000                    NaN                 447000             ND
# 8    100.905000                    NaN                 450000             ND
# 9    103.085211      490,000 - 830,000      500,000 - 778,000         Stable
# 10   101.361667      540,000 - 700,000      570,000 - 595,000       -8.49162
# 11    69.000000      395,000 - 470,000      350,000 - 425,000             -9
# 12   105.545500      680,000 - 750,000      650,000 - 860,000       4.362881
# 13    90.800000      580,000 - 825,000      580,000 - 700,000       -4.71464
# 14   133.895000                 800000                 740000           -7.5
# 15    91.425000      550,000 - 560,000      540,000 - 551,000         Stable
# 16    94.013750      440,000 - 690,000      470,000 - 600,000      -3.983566
# 17   133.500000                 535000                 550000       2.803738
# 18   113.435000                 460000                 495000       7.608696
# 19    81.671000      420,000 - 500,000      453,000 - 550,000      10.043478
# 20    76.085000                 498000      400,000 - 450,000     -14.658635
# 21   121.600000                    NaN                1168000             ND
# 22   109.810500                1400000  1,000,000 - 2,185,000          13.75
# 23   106.973333  1,150,000 - 1,230,000  1,200,000 - 1,420,000      10.014104
# 24   120.000000  1,060,000 - 1,405,000                1300000            8.1
# 25   124.367000      500,000 - 650,000      500,000 - 620,000         Stable
# 26    96.017500      420,000 - 648,000      500,000 - 600,000       4.562738
# 27   106.118000      500,000 - 680,000      540,000 - 675,000       2.881356
# 28   114.940000    920,000 - 1,300,000  1,150,000 - 1,238,000       7.676938
# 29    98.205000      499,000 - 995,000      640,000 - 760,000              5
#
#                  location                                    types      source
# 0      Mukim Kuala Lumpur         SINGLE STOREY LOW - COST TERRACE  2022/WP KL
# 1          Mukim Petaling         SINGLE STOREY LOW - COST TERRACE  2022/WP KL
# 2              Mukim Batu  SINGLE STOREY MEDIUM - LOW COST TERRACE  2022/WP KL
# 3              Mukim Batu  SINGLE STOREY MEDIUM - LOW COST TERRACE  2022/WP KL
# 4       Mukim Hulu Kelang  SINGLE STOREY MEDIUM - LOW COST TERRACE  2022/WP KL
# 5          Mukim Petaling  SINGLE STOREY MEDIUM - LOW COST TERRACE  2022/WP KL
# 6   SINGLE STOREY TERRACE                    SINGLE STOREY TERRACE  2022/WP KL
# 7   SINGLE STOREY TERRACE                    SINGLE STOREY TERRACE  2022/WP KL
# 8              Mukim Batu                    SINGLE STOREY TERRACE  2022/WP KL
# 9              Mukim Batu                    SINGLE STOREY TERRACE  2022/WP KL
# 10             Mukim Batu                    SINGLE STOREY TERRACE  2022/WP KL
# 11             Mukim Batu                    SINGLE STOREY TERRACE  2022/WP KL
# 12             Mukim Batu                    SINGLE STOREY TERRACE  2022/WP KL
# 13             Mukim Batu                    SINGLE STOREY TERRACE  2022/WP KL
# 14             Mukim Batu                    SINGLE STOREY TERRACE  2022/WP KL
# 15             Mukim Batu                    SINGLE STOREY TERRACE  2022/WP KL
# 16             Mukim Batu                    SINGLE STOREY TERRACE  2022/WP KL
# 17      Mukim Hulu Kelang                    SINGLE STOREY TERRACE  2022/WP KL
# 18           Mukim Cheras                    SINGLE STOREY TERRACE  2022/WP KL
# 19           Mukim Cheras                    SINGLE STOREY TERRACE  2022/WP KL
# 20     Mukim Kuala Lumpur                    SINGLE STOREY TERRACE  2022/WP KL
# 21     Mukim Kuala Lumpur                    SINGLE STOREY TERRACE  2022/WP KL
# 22     Mukim Kuala Lumpur                    SINGLE STOREY TERRACE  2022/WP KL
# 23     Mukim Kuala Lumpur                    SINGLE STOREY TERRACE  2022/WP KL
# 24     Mukim Kuala Lumpur                    SINGLE STOREY TERRACE  2022/WP KL
# 25     Mukim Kuala Lumpur                    SINGLE STOREY TERRACE  2022/WP KL
# 26     Mukim Kuala Lumpur                    SINGLE STOREY TERRACE  2022/WP KL
# 27     Mukim Kuala Lumpur                    SINGLE STOREY TERRACE  2022/WP KL
# 28     Mukim Kuala Lumpur                    SINGLE STOREY TERRACE  2022/WP KL
# 29        Mukim  Petaling                    SINGLE STOREY TERRACE  2022/WP KL

# %% [markdown]
# Bulk

# %%
"https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/WP KL/Jadual Harga dan Sewa WPKL LPH 2022.xlsx",
"https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/WP LABUAN/Jadual Harga dan Sewa  Labuan LPH 2022.xlsx",
"https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/WP PUTRAJAYA/Jadual Harga dan Sewa Putrajaya LPH 2022.xlsx",
"https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/KEDAH/Jadual Harga dan Sewa Kedah LPH 2022.xlsx",
"https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/PERLIS/Jadual Harga dan Sewa Perlis LPH 2022.xlsx",
"https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/PULAU PINANG/Jadual Harga dan Sewa Pulau Pinang LPH 2022.xls
"https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/SELANGOR/Jadual Harga dan Sewa Selangor LPH 2022.xlsx",
"https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/PAHANG/Jadual Harga dan Sewa Pahang LPH 2022.xlsx",
"https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/MELAKA/Jadual Harga dan Sewa Melaka LPH 2022.xlsx",
"https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/NEGERI SEMBILAN/Jadual Harga dan Sewa N. Sembilan LPH 2022.xlsx",
"https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/PERAK/Jadual Harga dan Sewa Perak LPH 2022.xlsx",
"https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/TERENGGANU/Jadual Harga dan Sewa Terengganu LPH 2022.xlsx",
"https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/KELANTAN/Jadual Harga dan Sewa Kelantan LPH 2022.xlsx",
"https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/JOHOR/Jadual Harga dan Sewa Johor LPH 2022.xlsx",
"https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/SABAH/Jadual Harga dan Sewa Sabah LPH 2022.xlsx",
"https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/SARAWAK/Jadual Harga dan Sewa Sarawak LPH 2022.xlsx",

# %%
import pandas as pd
from io import BytesIO
import requests
import numpy as np

# Sample URLs
urls = [
    "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/WP KL/Jadual Harga dan Sewa WPKL LPH 2022.xlsx",
    "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/WP LABUAN/Jadual Harga dan Sewa  Labuan LPH 2022.xlsx",
    "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/WP PUTRAJAYA/Jadual Harga dan Sewa Putrajaya LPH 2022.xlsx",
    "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/KEDAH/Jadual Harga dan Sewa Kedah LPH 2022.xlsx",
    "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/PERLIS/Jadual Harga dan Sewa Perlis LPH 2022.xlsx",
    # "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/PULAU PINANG/Jadual Harga dan Sewa Pulau Pinang LPH 2022.xlsx",
    "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/SELANGOR/Jadual Harga dan Sewa Selangor LPH 2022.xlsx",
    "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/PAHANG/Jadual Harga dan Sewa Pahang LPH 2022.xlsx",
    "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/MELAKA/Jadual Harga dan Sewa Melaka LPH 2022.xlsx",
    "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/NEGERI SEMBILAN/Jadual Harga dan Sewa N. Sembilan LPH 2022.xlsx",
    "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/PERAK/Jadual Harga dan Sewa Perak LPH 2022.xlsx",
    # "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/TERENGGANU/Jadual Harga dan Sewa Terengganu LPH 2022.xlsx",
    "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/KELANTAN/Jadual Harga dan Sewa Kelantan LPH 2022.xlsx",
    "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/JOHOR/Jadual Harga dan Sewa Johor LPH 2022.xlsx",
    # "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/SABAH/Jadual Harga dan Sewa Sabah LPH 2022.xlsx",
    "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/SARAWAK/Jadual Harga dan Sewa Sarawak LPH 2022.xlsx"
    ]

# Create an empty list to store DataFrames
dfs = []

# Specify the sheet names you want to read
target_sheets = ['.1']  # Sheets ending with '.1' or '.3'

# Iterate through each URL
for url in urls:
    # Get the content of the file from the URL
    response = requests.get(url)
    
    # Read sheets that match the criteria
    xls = pd.ExcelFile(BytesIO(response.content), engine='openpyxl')
    sheet_names = [sheet for sheet in xls.sheet_names if sheet.endswith(tuple(target_sheets))]
    
    # Extract relevant information from the URL
    url_parts = url.split('/')
    url_file = f"{url_parts[-3]}/{url_parts[-2]}"
    
    # Iterate through each sheet
    for sheet in sheet_names:
        # Read the sheet into a DataFrame
        df = pd.read_excel(xls, sheet_name=sheet, skiprows=5)#,
        df.columns = ['district_mukim','sample_size','avg_landsm','avg_floorsm','price_2021','price_2022','avg_pricePerct']
        df = df.iloc[1:]
        
        # Drop rows with all NaN values
        df = df.dropna(how='all')
        
        # Check if df[1] is NaN and use df[0] value for a new column 'location'
        df['location'] = np.where(pd.isna(df[df.columns[1]]), df[df.columns[0]], df[df.columns[1]])
        df['location'] = df['location'].astype(str)
                
        # Identify strings containing numbers and replace with NaN
        pattern = r'\d'  # Regular expression to match any digit
        df['location'] = df['location'].where(~df['location'].str.contains(pattern), np.nan)

        # Forward-fill the 'location' column
        df['location'] = df['location'].fillna(method='ffill')
        
        # Create a new column 'types' at rows where df[0] is in uppercase
        df['types'] = np.where(df[df.columns[0]].str.isupper(), df[df.columns[0]], np.nan)
        
        # Forward-fill the 'types' column until a different value is encountered
        df['types'] = df['types'].fillna(method='ffill')

        # Remove rows where 'district_mukim' is equal to 'location'
        df = df[df[df.columns[0]] != df[df.columns[7]]]
        
        # Assuming df is your DataFrame
        df = df.dropna(subset=['sample_size'])
                
        # Add a new column 'filename' with the extracted information
        df['source'] = url_file
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
final_result_df = pd.concat(dfs, ignore_index=True)

# Display the final result DataFrame
final_result_df
# Out:
# c:\Users\najmi.ariffin\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                 district_mukim  sample_size avg_landsm  \
# 0                 Salak South Low Cost Housing          1.0     102.19
# 1                     Bandar Baru Sri Petaling          1.0      143.0
# 2                                  Kepong Baru          1.0    132.847
# 3                           Taman Sri Segambut          1.0     136.56
# 4                              Wangsa Melawati          1.0      108.0
# ...                                        ...          ...        ...
# 7044  Bay Resort Condominium                            1.0        NaN
# 7045  Serene Height                                     3.0        NaN
# 7046  Bintulu Beach Resort Condominium                  2.0        NaN
# 7047  Dd Palm Spring Condominium                        1.0        NaN
# 7048  Parkcity Residence                                1.0        NaN
#
#       avg_floorsm price_2021         price_2022 avg_pricePerct  \
# 0       81.750000        NaN             200000             ND
# 1       86.405000        NaN             610000             ND
# 2      107.300000        NaN             530000             ND
# 3       96.575000        NaN             485000             ND
# 4      107.950000        NaN             630000             ND
# ...           ...        ...                ...            ...
# 7044   320.340000        NaN            1190000             ND
# 7045    45.666667        NaN  250,000 - 388,000             ND
# 7046   129.000000        NaN  520,000 - 550,000             ND
# 7047   204.380000        NaN             920000             ND
# 7048    31.120000     220000             230000           4.55
#
#                                         location  \
# 0                             Mukim Kuala Lumpur
# 1                                 Mukim Petaling
# 2                                     Mukim Batu
# 3                                     Mukim Batu
# 4                              Mukim Hulu Kelang
# ...                                          ...
# 7044                               Bahagian Miri
# 7045                               Bahagian Miri
# 7046  Bahagian Bintulu
# 7047  Bahagian Bintulu
# 7048  Bahagian Bintulu
#
#                                         types        source
# 0            SINGLE STOREY LOW - COST TERRACE    2022/WP KL
# 1            SINGLE STOREY LOW - COST TERRACE    2022/WP KL
# 2     SINGLE STOREY MEDIUM - LOW COST TERRACE    2022/WP KL
# 3     SINGLE STOREY MEDIUM - LOW COST TERRACE    2022/WP KL
# 4     SINGLE STOREY MEDIUM - LOW COST TERRACE    2022/WP KL
# ...                                       ...           ...
# 7044                              CONDOMINIUM  2022/SARAWAK
# 7045                              CONDOMINIUM  2022/SARAWAK
# 7046                              CONDOMINIUM  2022/SARAWAK
# 7047                              CONDOMINIUM  2022/SARAWAK
# 7048                              CONDOMINIUM  2022/SARAWAK
#
# [7049 rows x 10 columns]

# %%
woPPTGSBH = final_result_df

# %%
woPPTGSBH
# Out:
#                                 district_mukim  sample_size avg_landsm  \
# 0                 Salak South Low Cost Housing          1.0     102.19
# 1                     Bandar Baru Sri Petaling          1.0      143.0
# 2                                  Kepong Baru          1.0    132.847
# 3                           Taman Sri Segambut          1.0     136.56
# 4                              Wangsa Melawati          1.0      108.0
# ...                                        ...          ...        ...
# 7044  Bay Resort Condominium                            1.0        NaN
# 7045  Serene Height                                     3.0        NaN
# 7046  Bintulu Beach Resort Condominium                  2.0        NaN
# 7047  Dd Palm Spring Condominium                        1.0        NaN
# 7048  Parkcity Residence                                1.0        NaN
#
#       avg_floorsm price_2021         price_2022 avg_pricePerct  \
# 0       81.750000        NaN             200000             ND
# 1       86.405000        NaN             610000             ND
# 2      107.300000        NaN             530000             ND
# 3       96.575000        NaN             485000             ND
# 4      107.950000        NaN             630000             ND
# ...           ...        ...                ...            ...
# 7044   320.340000        NaN            1190000             ND
# 7045    45.666667        NaN  250,000 - 388,000             ND
# 7046   129.000000        NaN  520,000 - 550,000             ND
# 7047   204.380000        NaN             920000             ND
# 7048    31.120000     220000             230000           4.55
#
#                                         location  \
# 0                             Mukim Kuala Lumpur
# 1                                 Mukim Petaling
# 2                                     Mukim Batu
# 3                                     Mukim Batu
# 4                              Mukim Hulu Kelang
# ...                                          ...
# 7044                               Bahagian Miri
# 7045                               Bahagian Miri
# 7046  Bahagian Bintulu
# 7047  Bahagian Bintulu
# 7048  Bahagian Bintulu
#
#                                         types        source
# 0            SINGLE STOREY LOW - COST TERRACE    2022/WP KL
# 1            SINGLE STOREY LOW - COST TERRACE    2022/WP KL
# 2     SINGLE STOREY MEDIUM - LOW COST TERRACE    2022/WP KL
# 3     SINGLE STOREY MEDIUM - LOW COST TERRACE    2022/WP KL
# 4     SINGLE STOREY MEDIUM - LOW COST TERRACE    2022/WP KL
# ...                                       ...           ...
# 7044                              CONDOMINIUM  2022/SARAWAK
# 7045                              CONDOMINIUM  2022/SARAWAK
# 7046                              CONDOMINIUM  2022/SARAWAK
# 7047                              CONDOMINIUM  2022/SARAWAK
# 7048                              CONDOMINIUM  2022/SARAWAK
#
# [7049 rows x 10 columns]

# %%
woPPTGSBH.shape[0]
# Out:
# 7049

# %%
# !pip install --upgrade xlrd
# !pip install --upgrade openpyxl
# Out:
# Requirement already satisfied: xlrd in c:\users\najmi.ariffin\appdata\local\programs\python\python310\lib\site-packages (2.0.1)
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: openpyxl in c:\users\najmi.ariffin\appdata\local\programs\python\python310\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\najmi.ariffin\appdata\local\programs\python\python310\lib\site-packages (from openpyxl) (1.1.0)
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# PPinang

# %%
import pandas as pd
from io import BytesIO
import requests
import numpy as np
import xlrd
import openpyxl

# Sample URLs
urls = [
    "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/PULAU%20PINANG/Jadual%20Harga%20dan%20Sewa%20Pulau%20Pinang%20LPH%202022.xls"
    # "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/TERENGGANU/Jadual%20Harga%20dan%20Sewa%20Terengganu%20LPH%202022.xlsx"
    # "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/SABAH/Jadual%20Harga%20dan%20Sewa%20Sabah%20LPH%202022.xlsx"
 ]

# Create an empty list to store DataFrames
dfs = []

# Specify the sheet names you want to read
target_sheets = ['.1']  # Sheets ending with '.1' or '.3'

# Iterate through each URL
for url in urls:
    # Get the content of the file from the URL
    response = requests.get(url)
    
    # Read sheets that match the criteria
    xls = pd.ExcelFile(BytesIO(response.content), engine='xlrd')
    sheet_names = [sheet for sheet in xls.sheet_names if sheet.endswith(tuple(target_sheets))]
    
    # Extract relevant information from the URL
    url_parts = url.split('/')
    url_file = f"{url_parts[-3]}/{url_parts[-2]}"
    
    # Iterate through each sheet
    for sheet in sheet_names:
        # Read the sheet into a DataFrame
        df = pd.read_excel(xls, sheet_name=sheet, skiprows=5)#,
        df.columns = ['district_mukim','sample_size','avg_landsm','avg_floorsm','price_2021','price_2022','avg_pricePerct']
        df = df.iloc[1:]
        
        # Drop rows with all NaN values
        df = df.dropna(how='all')
        
        # Check if df[1] is NaN and use df[0] value for a new column 'location'
        df['location'] = np.where(pd.isna(df[df.columns[1]]), df[df.columns[0]], df[df.columns[1]])
        df['location'] = df['location'].astype(str)
                
        # Identify strings containing numbers and replace with NaN
        pattern = r'\d'  # Regular expression to match any digit
        df['location'] = df['location'].where(~df['location'].str.contains(pattern), np.nan)

        # Forward-fill the 'location' column
        df['location'] = df['location'].fillna(method='ffill')
        
        # Create a new column 'types' at rows where df[0] is in uppercase
        df['types'] = np.where(df[df.columns[0]].str.isupper(), df[df.columns[0]], np.nan)
        
        # Forward-fill the 'types' column until a different value is encountered
        df['types'] = df['types'].fillna(method='ffill')

        # Remove rows where 'district_mukim' is equal to 'location'
        df = df[df[df.columns[0]] != df[df.columns[7]]]
        
        # Assuming df is your DataFrame
        df = df.dropna(subset=['sample_size'])
                
        # Add a new column 'filename' with the extracted information
        df['source'] = url_file
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
final_result_df = pd.concat(dfs, ignore_index=True)

# Display the final result DataFrame
woPPonly = final_result_df

# %%
woPPonly
# Out:
#                                    district_mukim  sample_size avg_landsm  \
# 0                                  Bertam Perdana          5.0        102
# 1                                  Taman Cempedak          1.0        102
# 2                               Taman Merbau Jaya          1.0        102
# 3                              Taman Sri Menerong          3.0         93
# 4    Taman Alma Jaya (Fasa 1)                              1.0         93
# ..                                            ...          ...        ...
# 917                              Residensi Sejati          3.0          -
# 918                             The Prominence             2.0          -
# 919                                           NaN          3.0          -
# 920                 The Signature Condominium              2.0          -
# 921                                  Vertu Resort          4.0          -
#
#      avg_floorsm         price_2021         price_2022 avg_pricePerct  \
# 0          61.00  200,000 - 225,000  184,000 - 235,000         Stable
# 1          63.00  145,000 - 160,000             155000         Stable
# 2          65.00             200000             218000              9
# 3          55.00  150,000 - 178,000  170,000 - 185,000           10.8
# 4          60.76                NaN             240000             ND
# ..           ...                ...                ...            ...
# 917       116.00  465,000 - 563,000  465,000 - 570,000         Stable
# 918       118.00  410,000 - 450,000             450000           10.8
# 919       140.00  470,000 - 550,000  460,000 - 600,000         Stable
# 920       101.00  390,000 - 435,000  430,000 - 450,000            8.1
# 921        96.00  490,000 - 550,000  475,000 - 499,000           -4.2
#
#                    location                           types  \
# 0      Seberang Perai Utara  SINGLE STOREY LOW-COST TERRACE
# 1      Seberang Perai Utara  SINGLE STOREY LOW-COST TERRACE
# 2      Seberang Perai Utara  SINGLE STOREY LOW-COST TERRACE
# 3      Seberang Perai Utara  SINGLE STOREY LOW-COST TERRACE
# 4     Seberang Perai Tengah  SINGLE STOREY LOW-COST TERRACE
# ..                      ...                             ...
# 917   Seberang Perai Tengah                     CONDOMINIUM
# 918   Seberang Perai Tengah                     CONDOMINIUM
# 919   Seberang Perai Tengah                     CONDOMINIUM
# 920   Seberang Perai Tengah                     CONDOMINIUM
# 921  Seberang Perai Selatan                     CONDOMINIUM
#
#                   source
# 0    2022/PULAU%20PINANG
# 1    2022/PULAU%20PINANG
# 2    2022/PULAU%20PINANG
# 3    2022/PULAU%20PINANG
# 4    2022/PULAU%20PINANG
# ..                   ...
# 917  2022/PULAU%20PINANG
# 918  2022/PULAU%20PINANG
# 919  2022/PULAU%20PINANG
# 920  2022/PULAU%20PINANG
# 921  2022/PULAU%20PINANG
#
# [922 rows x 10 columns]

# %%
woPPonly.shape[0]
# Out:
# 922

# %% [markdown]
# Terengganu

# %%
import pandas as pd
from io import BytesIO
import requests
import numpy as np
import xlrd
import openpyxl

# Sample URLs
urls = [
    "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/TERENGGANU/Jadual%20Harga%20dan%20Sewa%20Terengganu%20LPH%202022.xlsx"
    # "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/SABAH/Jadual%20Harga%20dan%20Sewa%20Sabah%20LPH%202022.xlsx"
 ]

# Create an empty list to store DataFrames
dfs = []

# Specify the sheet names you want to read
target_sheets = ['.1']  # Sheets ending with '.1' or '.3'

# Iterate through each URL
for url in urls:
    # Get the content of the file from the URL
    response = requests.get(url)
    
    # Read sheets that match the criteria
    xls = pd.ExcelFile(BytesIO(response.content))
    sheet_names = [sheet for sheet in xls.sheet_names if sheet.endswith(tuple(target_sheets))]
    
    # Extract relevant information from the URL
    url_parts = url.split('/')
    url_file = f"{url_parts[-3]}/{url_parts[-2]}"
    
    # Iterate through each sheet
    for sheet in sheet_names:
        # Read the sheet into a DataFrame
        df = pd.read_excel(xls, sheet_name=sheet, skiprows=4)#,
        df = df.iloc[1:,:7]
        df.columns = ['district_mukim','sample_size','avg_landsm','avg_floorsm','price_2021','price_2022','avg_pricePerct']
        
        # Drop rows with all NaN values
        df = df.dropna(how='all')
        
        # Check if df[1] is NaN and use df[0] value for a new column 'location'
        df['location'] = np.where(pd.isna(df[df.columns[1]]), df[df.columns[0]], df[df.columns[1]])
        df['location'] = df['location'].astype(str)
                
        # Identify strings containing numbers and replace with NaN
        pattern = r'\d'  # Regular expression to match any digit
        df['location'] = df['location'].where(~df['location'].str.contains(pattern), np.nan)

        # Forward-fill the 'location' column
        df['location'] = df['location'].fillna(method='ffill')
        
        # Create a new column 'types' at rows where df[0] is in uppercase
        df['types'] = np.where(df[df.columns[0]].str.isupper(), df[df.columns[0]], np.nan)
        
        # Forward-fill the 'types' column until a different value is encountered
        df['types'] = df['types'].fillna(method='ffill')

        # Remove rows where 'district_mukim' is equal to 'location'
        df = df[df[df.columns[0]] != df[df.columns[7]]]
        
        # Assuming df is your DataFrame
        # df = df.dropna(subset=['sample_size'])
                
        # Add a new column 'filename' with the extracted information
        df['source'] = url_file
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
final_result_df = pd.concat(dfs, ignore_index=True)

# Display the final result DataFrame
woTRGonly = final_result_df

# %%
woTRGonly
# Out:
#                                    district_mukim  sample_size  avg_landsm  \
# 0                                          Belara          1.0         111
# 1                                      Alor Jambu          1.0         107
# 2                                      Gong Badak          5.0       122.4
# 3                                 Mengabang Lekor          1.0         103
# 4                                  Seberang Takir          3.0  111.333333
# ..                                            ...          ...         ...
# 301      Pangsapuri Ladang Tok Pelam (Tingkat 20)          1.0           -
# 302  Pangsapuri Taman Puncak Kemajuan (Tingkat 5)          1.0           -
# 303               Desa Ibai Apartment (Tingkat 2)          1.0           -
# 304                   Icon Residence (Tingkat 16)          1.0           -
# 305                   Icon Residence (Tingkat 19)          1.0           -
#
#      avg_floorsm         price_2021         price_2022 avg_pricePerct  \
# 0      90.655000             150000             160000       6.666667
# 1     100.100000             170000             170000         Stable
# 2     101.292000  150,000 - 190,000  150,000 - 210,000       6.132075
# 3      78.030000             120000             130000       8.333333
# 4      87.138333             200000  190,000 - 220,000         Stable
# ..           ...                ...                ...            ...
# 301    78.000000                NaN             310000             ND
# 302   122.630000                NaN             380000             ND
# 303   125.000000                NaN             365000             ND
# 304   115.000000                NaN             570000             ND
# 305   115.000000                NaN             570000             ND
#
#              location                             types           source
# 0    Kuala Terengganu  SINGLE STOREY LOW - COST TERRACE  2022/TERENGGANU
# 1         Kuala Nerus  SINGLE STOREY LOW - COST TERRACE  2022/TERENGGANU
# 2         Kuala Nerus  SINGLE STOREY LOW - COST TERRACE  2022/TERENGGANU
# 3         Kuala Nerus  SINGLE STOREY LOW - COST TERRACE  2022/TERENGGANU
# 4         Kuala Nerus  SINGLE STOREY LOW - COST TERRACE  2022/TERENGGANU
# ..                ...                               ...              ...
# 301  Kuala Terengganu                        PANGSAPURI  2022/TERENGGANU
# 302  Kuala Terengganu                        PANGSAPURI  2022/TERENGGANU
# 303  Kuala Terengganu                       CONDOMINIUM  2022/TERENGGANU
# 304  Kuala Terengganu                       CONDOMINIUM  2022/TERENGGANU
# 305  Kuala Terengganu                       CONDOMINIUM  2022/TERENGGANU
#
# [306 rows x 10 columns]

# %%
import pandas as pd
from io import BytesIO
import requests
import numpy as np
import xlrd
import openpyxl

# Sample URLs
urls = [
    "https://napic2.jpph.gov.my/storage/app/media//3-penerbitan/pasaran-harta-tanah/laporan-pasaran-harta-tahunan/2022/SABAH/Jadual%20Harga%20dan%20Sewa%20Sabah%20LPH%202022.xlsx"
 ]

# Create an empty list to store DataFrames
dfs = []

# Specify the sheet names you want to read
target_sheets = ['.1']  # Sheets ending with '.1' or '.3'

# Iterate through each URL
for url in urls:
    # Get the content of the file from the URL
    response = requests.get(url)
    
    # Read sheets that match the criteria
    xls = pd.ExcelFile(BytesIO(response.content))
    sheet_names = [sheet for sheet in xls.sheet_names if sheet.endswith(tuple(target_sheets))]
    
    # Extract relevant information from the URL
    url_parts = url.split('/')
    url_file = f"{url_parts[-3]}/{url_parts[-2]}"
    
    # Iterate through each sheet
    for sheet in sheet_names:
        # Read the sheet into a DataFrame
        df = pd.read_excel(xls, sheet_name=sheet, skiprows=5)#,
        df = df.iloc[1:,:7]
        df.columns = ['district_mukim','sample_size','avg_landsm','avg_floorsm','price_2021','price_2022','avg_pricePerct']
        
        # Drop rows with all NaN values
        df = df.dropna(how='all')
        
        # Check if df[1] is NaN and use df[0] value for a new column 'location'
        df['location'] = np.where(pd.isna(df[df.columns[1]]), df[df.columns[0]], df[df.columns[1]])
        df['location'] = df['location'].astype(str)
                
        # Identify strings containing numbers and replace with NaN
        pattern = r'\d'  # Regular expression to match any digit
        df['location'] = df['location'].where(~df['location'].str.contains(pattern), np.nan)

        # Forward-fill the 'location' column
        df['location'] = df['location'].fillna(method='ffill')
        
        # Create a new column 'types' at rows where df[0] is in uppercase
        df['types'] = np.where(df[df.columns[0]].str.isupper(), df[df.columns[0]], np.nan)
        
        # Forward-fill the 'types' column until a different value is encountered
        df['types'] = df['types'].fillna(method='ffill')

        # Remove rows where 'district_mukim' is equal to 'location'
        df = df[df[df.columns[0]] != df[df.columns[7]]]
        
        # Assuming df is your DataFrame
        # df = df.dropna(subset=['sample_size'])
                
        # Add a new column 'filename' with the extracted information
        df['source'] = url_file
        df = df.dropna(subset='district_mukim', axis=0)
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
final_result_df = pd.concat(dfs, ignore_index=True)

# Display the final result DataFrame
woSBHonly = final_result_df

# %%
woSBHonly
# Out:
#                      district_mukim  sample_size  avg_landsm  avg_floorsm  \
# 0                Taman Emas Takapan          1.0       209.0        84.00
# 1                     Taman Selagon          1.0       212.0        78.00
# 2                Taman Sri Panglima          3.0       149.0        60.00
# 3                       Taman Adika          1.0       186.0        79.00
# 4               Taman Adika Phase 3          1.0       181.0        77.00
# ..                              ...          ...         ...          ...
# 536         The Riverside Residence          2.0         NaN        89.00
# 537  Kingfisher Putatan Condominium          1.0         NaN        94.00
# 538           Sri Utama Condominium          1.0         NaN       115.93
# 539         Utama South Condominium          4.0         NaN       103.21
# 540        Kuhara Court Condominium          1.0         NaN        94.00
#
#             price_2021         price_2022 avg_pricePerct   location  \
# 0                  NaN             235000             ND   Beaufort
# 1                  NaN             250000             ND   Beaufort
# 2    210,000 - 220,000  180,000 - 250,000         Stable   Beaufort
# 3               240000             260000       8.333333   Keningau
# 4               280000             260000      -7.142857   Keningau
# ..                 ...                ...            ...        ...
# 536                NaN  420,000 - 465,000             ND  Penampang
# 537                NaN             485000             ND    Putatan
# 538             340000             362500       6.617647   Sandakan
# 539             350000  330,000 - 400,000       3.928571   Sandakan
# 540                NaN             290000             ND      Tawau
#
#                       types      source
# 0    SINGLE STOREY TERRACED  2022/SABAH
# 1    SINGLE STOREY TERRACED  2022/SABAH
# 2    SINGLE STOREY TERRACED  2022/SABAH
# 3    SINGLE STOREY TERRACED  2022/SABAH
# 4    SINGLE STOREY TERRACED  2022/SABAH
# ..                      ...         ...
# 536                     R55  2022/SABAH
# 537                     R55  2022/SABAH
# 538                     R55  2022/SABAH
# 539                     R55  2022/SABAH
# 540                     R55  2022/SABAH
#
# [541 rows x 10 columns]

# %% [markdown]
# All

# %%
alloc = pd.concat([woPPTGSBH, woPPonly, woTRGonly, woSBHonly], axis=0)
alloc.head()
# Out:
#                  district_mukim  sample_size avg_landsm  avg_floorsm  \
# 0  Salak South Low Cost Housing          1.0     102.19       81.750
# 1      Bandar Baru Sri Petaling          1.0      143.0       86.405
# 2                   Kepong Baru          1.0    132.847      107.300
# 3            Taman Sri Segambut          1.0     136.56       96.575
# 4               Wangsa Melawati          1.0      108.0      107.950
#
#   price_2021 price_2022 avg_pricePerct            location  \
# 0        NaN     200000             ND  Mukim Kuala Lumpur
# 1        NaN     610000             ND      Mukim Petaling
# 2        NaN     530000             ND          Mukim Batu
# 3        NaN     485000             ND          Mukim Batu
# 4        NaN     630000             ND   Mukim Hulu Kelang
#
#                                      types      source
# 0         SINGLE STOREY LOW - COST TERRACE  2022/WP KL
# 1         SINGLE STOREY LOW - COST TERRACE  2022/WP KL
# 2  SINGLE STOREY MEDIUM - LOW COST TERRACE  2022/WP KL
# 3  SINGLE STOREY MEDIUM - LOW COST TERRACE  2022/WP KL
# 4  SINGLE STOREY MEDIUM - LOW COST TERRACE  2022/WP KL

# %%
alloc.shape[0]
# Out:
# 8818

# %%
print(woPPTGSBH.shape[0])
print(woPPonly.shape[0])
print(woTRGonly.shape[0])
print(woSBHonly.shape[0])
# Out:
# 7049
# 922
# 306
# 541

# %%
7049+922+306+541
# Out:
# 8818

# %%
alloc[['price_2021', 'price_2022']] = alloc[['price_2021', 'price_2022']].replace({',': ''}, regex=True)

# %%
alloc.head()
# Out:
#                  district_mukim  sample_size avg_landsm  avg_floorsm  \
# 0  Salak South Low Cost Housing          1.0     102.19       81.750
# 1      Bandar Baru Sri Petaling          1.0      143.0       86.405
# 2                   Kepong Baru          1.0    132.847      107.300
# 3            Taman Sri Segambut          1.0     136.56       96.575
# 4               Wangsa Melawati          1.0      108.0      107.950
#
#   price_2021 price_2022 avg_pricePerct            location  \
# 0        NaN     200000             ND  Mukim Kuala Lumpur
# 1        NaN     610000             ND      Mukim Petaling
# 2        NaN     530000             ND          Mukim Batu
# 3        NaN     485000             ND          Mukim Batu
# 4        NaN     630000             ND   Mukim Hulu Kelang
#
#                                      types      source
# 0         SINGLE STOREY LOW - COST TERRACE  2022/WP KL
# 1         SINGLE STOREY LOW - COST TERRACE  2022/WP KL
# 2  SINGLE STOREY MEDIUM - LOW COST TERRACE  2022/WP KL
# 3  SINGLE STOREY MEDIUM - LOW COST TERRACE  2022/WP KL
# 4  SINGLE STOREY MEDIUM - LOW COST TERRACE  2022/WP KL

# %%
alloc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8818 entries, 0 to 540
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   district_mukim  8595 non-null   object
#  1   sample_size     8818 non-null   float64
#  2   avg_landsm      7754 non-null   object
#  3   avg_floorsm     8818 non-null   float64
#  4   price_2021      4676 non-null   object
#  5   price_2022      8818 non-null   object
#  6   avg_pricePerct  8818 non-null   object
#  7   location        8818 non-null   object
#  8   types           8818 non-null   object
#  9   source          8818 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 757.8+ KB

# %%
alloc.to_csv('napic_jual2022.csv', index=False)

# %%
alloc.columns
# Out:
# Index(['district_mukim', 'sample_size', 'avg_landsm', 'avg_floorsm',
#        'price_2021', 'price_2022', 'avg_pricePerct', 'location', 'types',
#        'source'],
#       dtype='object')

# %%
alloc.groupby('source').size()
# Out:
# source
# 2022/JOHOR               966
# 2022/KEDAH               918
# 2022/KELANTAN            326
# 2022/MELAKA              453
# 2022/NEGERI SEMBILAN     647
# 2022/PAHANG              588
# 2022/PERAK              1295
# 2022/PERLIS               91
# 2022/PULAU%20PINANG      922
# 2022/SABAH               541
# 2022/SARAWAK             720
# 2022/TERENGGANU          306
# 2022/WP KL               995
# 2022/WP LABUAN            36
# 2022/WP PUTRAJAYA         14
# dtype: int64

# %%
# alloc.query("types == 'FLAT'")
flat_mask = alloc['types'].str.contains('FLAT')
flat_df = alloc[flat_mask]
flat_df
# Out:
#                          district_mukim  sample_size avg_landsm  avg_floorsm  \
# 315           Flat DBKL Jalan Hang Tuah          2.0        NaN        42.00
# 316     PKNS Flat(Jalan Raja Muda Musa)          1.0        NaN        78.00
# 317                        PPR Pudu Ulu          1.0        NaN        60.00
# 318                       Pudu Impian 1          3.0        NaN        62.00
# 319  Rancangan Perumahan Sentul  Fasa 3          2.0        NaN        49.00
# ..                                  ...          ...        ...          ...
# 387                         Taman Fajar          2.0        NaN        63.00
# 388          Taman Pasir Putih Phase 3C          4.0        NaN        56.00
# 389                   Taman Telipok Ria         17.0        NaN        57.00
# 390                        Taman Sejati          6.0        NaN        53.02
# 391                      Telipok Square          3.0        NaN        59.00
#
#           price_2021       price_2022 avg_pricePerct  \
# 315           100000    8500 - 126000            5.5
# 316              NaN           450000             ND
# 317              NaN           170000             ND
# 318  160000 - 185000           190000       6.082725
# 319           150000  145000 - 150000         Stable
# ..               ...              ...            ...
# 387           150000  140000 - 168000       2.666667
# 388  160000 - 165000  160000 - 180000       6.923077
# 389  140000 - 160000  135000 - 170000         Stable
# 390  110000 - 130000  110000 - 130000         Stable
# 391  120000 - 130000           130000       2.631309
#
#                            location                           types  \
# 315  RUMAH PANGSA /FLAT KOS  RENDAH  RUMAH PANGSA /FLAT KOS  RENDAH
# 316  RUMAH PANGSA /FLAT KOS  RENDAH  RUMAH PANGSA /FLAT KOS  RENDAH
# 317  RUMAH PANGSA /FLAT KOS  RENDAH  RUMAH PANGSA /FLAT KOS  RENDAH
# 318  RUMAH PANGSA /FLAT KOS  RENDAH  RUMAH PANGSA /FLAT KOS  RENDAH
# 319  RUMAH PANGSA /FLAT KOS  RENDAH  RUMAH PANGSA /FLAT KOS  RENDAH
# ..                              ...                             ...
# 387                   Kota Kinabalu               LOW - COST FLAT
# 388                         Putatan               LOW - COST FLAT
# 389                          Tuaran               LOW - COST FLAT
# 390                        Sandakan            MEDIUM - COST FLAT
# 391                          Tuaran            MEDIUM - COST FLAT
#
#          source
# 315  2022/WP KL
# 316  2022/WP KL
# 317  2022/WP KL
# 318  2022/WP KL
# 319  2022/WP KL
# ..          ...
# 387  2022/SABAH
# 388  2022/SABAH
# 389  2022/SABAH
# 390  2022/SABAH
# 391  2022/SABAH
#
# [401 rows x 10 columns]

# %%
flat_df.to_csv('flat_df_harga.csv', index=False)

# %%
flat_sewa = pd.read_csv('flat_df_sewa.csv')

# %%
combine = pd.concat([flat_df,flat_sewa], axis=0).reset_index()

# %%
combine.columns
# Out:
# Index(['index', 'district_mukim', 'sample_size', 'avg_landsm', 'avg_floorsm',
#        'price_2021', 'price_2022', 'avg_pricePerct', 'location', 'types',
#        'source', 'rental_2021', 'rental_2022'],
#       dtype='object')

# %%
sugscope = combine[['district_mukim','location', 'source','types', 'price_2021', 'price_2022']]

# %%
sugscope.to_csv('cadangan_strategi_lowcostarea_NAPIC2022.csv', index=False)
