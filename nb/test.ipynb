# %%
# !pip install pandas pyarrow fastparquet

# %%
# If not already installed, do: pip install pandas fastparquet
import pandas as pd

URL_DATA = 'https://storage.googleapis.com/dosm-public-dashboards/kawasanku_admin_jitter.parquet'

df = pd.read_parquet(URL_DATA)
if 'date' in df.columns: df['date'] = pd.to_datetime(df['date'])

df
# Out:
#     area_type               area  total_area_x  max_elevation_x  ruggedness_x  \
# 0       state              Johor         0.088           -0.166        -0.650
# 1       state              Kedah         0.007            0.113        -0.048
# 2       state           Kelantan         0.053            0.220         0.875
# 3       state             Melaka        -0.808           -0.658         0.262
# 4       state    Negeri Sembilan        -0.238           -0.038         0.602
# ..        ...                ...           ...              ...           ...
# 171  district             Beluru         0.168            0.110         0.137
# 172  district        Telang Usan         0.397            0.228         0.102
# 173  district  W.P. Kuala Lumpur        -0.566           -0.452        -0.356
# 174  district        W.P. Labuan        -0.647           -0.649        -0.536
# 175  district     W.P. Putrajaya        -0.670           -0.590        -0.555
#
# ...

# %%
# If not already installed, do: pip install pandas fastparquet
import pandas as pd

# URL_DATA = 'https://storage.googleapis.com/dosm-public-dashboards/kawasanku_admin_pyramid.parquet'
URL_DATA = 'https://storage.googleapis.com/dosm-public-dashboards/kawasanku_admin_barmeter.parquet'

df = pd.read_parquet(URL_DATA)
if 'date' in df.columns: df['date'] = pd.to_datetime(df['date'])

df
# Out:
#      area_type            area        chart       variable      value
# 0      country        Malaysia          sex           male  52.288396
# 1      country        Malaysia          sex         female  47.711604
# 2      country        Malaysia     agegroup          child  26.417660
# 3      country        Malaysia     agegroup        working  68.293245
# 4      country        Malaysia     agegroup        elderly   5.289095
# ...        ...             ...          ...            ...        ...
# 3712     state  W.P. Putrajaya  nationality        foreign   2.583286
# 3713     state  W.P. Putrajaya      marital  never_married  27.733099
# 3714     state  W.P. Putrajaya      marital        married  68.020471
# 3715     state  W.P. Putrajaya      marital        widowed   2.036675
# 3716     state  W.P. Putrajaya      marital       divorced   2.209755
#
# [3717 rows x 5 columns]

# %%
df.query('area_type == "country"')
# Out:
#    area_type      area        chart       variable      value
# 0    country  Malaysia          sex           male  52.288396
# 1    country  Malaysia          sex         female  47.711604
# 2    country  Malaysia     agegroup          child  26.417660
# 3    country  Malaysia     agegroup        working  68.293245
# 4    country  Malaysia     agegroup        elderly   5.289095
# 5    country  Malaysia    ethnicity           bumi  69.395464
# 6    country  Malaysia    ethnicity        chinese  23.162703
# 7    country  Malaysia    ethnicity         indian   6.717156
# 8    country  Malaysia    ethnicity          other   0.724676
# 9    country  Malaysia     religion         muslim  63.518401
# 10   country  Malaysia     religion      christian   9.064056
# 11   country  Malaysia     religion       buddhist  18.697297
# 12   country  Malaysia     religion          hindu   6.069737
# 13   country  Malaysia     religion          other   0.878814
# ...

# %%
set(df.area)
# Out:
# {'Alor Gajah',
#  'Asajaya',
#  'Bachok',
#  'Bagan Datuk',
#  'Baling',
#  'Bandar Baharu',
#  'Barat Daya',
#  'Batang Padang',
#  'Batu Pahat',
#  'Bau',
#  'Beaufort',
#  'Belaga',
#  'Beluran',
#  'Beluru',
#  'Bentong',
#  'Bera',
#  'Besut',
#  'Betong',
#  'Bintulu',
#  'Bukit Mabong',
#  'Cameron Highlands',
#  'Dalat',
#  'Daro',
#  'Dungun',
#  'Gombak',
#  'Gua Musang',
#  'Hilir Perak',
#  'Hulu Perak',
#  'Hulu Terengganu',
#  'Jasin',
#  'Jelebu',
#  'Jeli',
#  'Jempol',
#  'Jerantut',
#  'Johor',
#  'Johor Bahru',
#  'Julau',
#  'Kabong',
#  'Kalabakan',
#  'Kampar',
#  'Kanowit',
#  'Kapit',
#  'Kecil Lojing',
#  'Kedah',
#  'Kelantan',
#  'Kemaman',
#  'Keningau',
#  'Kerian',
#  'Kinabatangan',
#  'Kinta',
#  'Klang',
#  'Kluang',
#  'Kota Belud',
#  'Kota Bharu',
#  'Kota Kinabalu',
#  'Kota Marudu',
#  'Kota Setar',
#  'Kota Tinggi',
#  'Kuala Kangsar',
#  'Kuala Krai',
#  'Kuala Langat',
#  'Kuala Muda',
#  'Kuala Nerus',
#  'Kuala Penyu',
#  'Kuala Pilah',
# ...

# %%
# !pip install openpyxl
# import openpyxl
# Out:
# ...
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\najmi.ariffin\Downloads\src_population\malaysia.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\najmi.ariffin\env-python\general\main\lib\site-packages\pandas\compat\_optional.py:141, in import_optional_dependency(name, extra, errors, min_version)
#     140 try:
# --> 141     module = importlib.import_module(name)
#     142 except ImportError:
#
# File C:\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
df
